# %% [markdown]
# # Extraction of Exponential-Integrate-and-Fire Models From Blue Brain Project Cells

# %%
## import the required modules 
from neuron import h
import numpy as np
from scipy.optimize import curve_fit
import warnings
from matplotlib import pyplot as plt

# %% [markdown]
# ### Loading Data of Requested Cell Type

# %%
## load the output data from simulation of the BBP cell of interest.
## Simulations of each neuron are held according to experimental process explained in (Badel et al., 2008) 
## with 8 types of noisy input (Ornstein-Uhlenbeck process). Experiment array containing V_mem, I_inj, t, dV/dt and
## spike times are stored in .npy files. In silico experimentation of BBP cells on Python requires NEURON and file of the cells, 
## thus, this part isn't shown in this Notebook. To see the methods to generate the experimental process of EIF extraction
## on BBP cells, see https://github.com/oykur > EIF Extraction Kit
warnings.filterwarnings("ignore")                         ## due to infinities in the calculation of capacitance, some warnings that occur can be made invisible
cell_type = input("Write the cell type of interest among: STPC, TTPC2, UTPC: ") ## More cell types will be added soon...
print(cell_type + " is selected.")
spiketimes = np.load(cell_type+"_spiketimes.npy")         ## load the spike times obtained by patch-clamping a BBP neuron with 8 types of Ornstein-Uhlenbeck Process
experiment_array = np.load(cell_type+"_exp_array.npy")    ## experiment output is stored in an array, contains membrane potential (V_mem), injected current (I_inj), time (t), and potential change over time (dV/dt) respectively.
print("Next step may take few minutes.")
# Out:
# Write the cell type of interest among: STPC, TTPC2, UTPC: UTPC
# UTPC is selected.
# Next step may take few minutes.

# %% [markdown]
# ### Filtering the 200 ms After Each Spike From the Data

# %%
dt = 0.025                                          ## ms - Integration time step. 

V_maxes = np.array([])                              ## array to store the maximum points of action potentials (AP)
V_maxes_ind = np.array([])                          ## array to store the indexes of maximum points

V_s = int(spiketimes[0])                            ## time of the first spike 
V_s_index = np.argmax(experiment_array[2,:] > V_s)  ## index of the time point of V_s in the experiment array
V_s_plus = (np.argmax(experiment_array[0][V_s_index:(V_s_index+100)])) ## V_max should be V_s_plus elements after the V_s_index
V_max = V_s_plus*0.025+ V_s                         ## find the time point of the peak of spike
V_maxes = np.append(V_maxes, V_max)                 ## store time of the peak
V_max_array_ind = int(V_s_index+V_s_plus)           ## find index of the peak in the experiment array
V_max_last_ind = V_max_array_ind                    ## to be used in filtering, store this spike as the last spike
V_last_spike = V_s

not_keeping_next = 0 ## if there are one or more spikes in the 200 ms after a spike, in the interval that will be filtered, 
                     ## the last spike in this interval should be found and filtering should be from peak of the first spike to 
                     ## 200 ms after the last spike. Thus, if the current spike is still in the 200 ms interval, not_keeping_next = 1
                     ## and it is changed back to 0 when the filtering is completed with the last spike of the interval. 
spike = 1            ## start from the second spike

while spike < len(spiketimes):                      ## till the end of the spikes, continue filtering
    V_s = int(spiketimes[spike]) 
    V_s_index = np.argmax(experiment_array[2,:] > V_s) 
    V_s_plus = (np.argmax(experiment_array[0][V_s_index:(V_s_index+100)]))
    V_max = V_s_plus*0.025+ V_s                     ## use V_s to find where AP has peaked
    V_maxes = np.append(V_maxes, V_max)
    V_max_array_ind = int(V_s_index+V_s_plus)

    if V_last_spike + 200 >= V_s and not_keeping_next ==0:
        print("This is the "+str(spike)+"th spike. We will skip that.")
        V_old = V_last_spike                        ## store the first spike in the 200 ms period as the old spike
        V_old_ind = V_max_last_ind  
        not_keeping_next = 1                        ## this spike will not be filtered, yet
        spike += 1                                  ## continue with the next spike
    elif V_last_spike + 200 >= V_s and not_keeping_next ==1:     ## current spike is still in the 200 ms period, no filtering, skip this spike
        print("This is the "+str(spike)+"th spike. We will skip that.")
        spike += 1
    elif V_last_spike + 200 < V_s and not_keeping_next ==1:      ## current spike is out of the 200 ms period, filtering step
        V_max_last_200 = (V_max_last_ind+int(200/dt))            ## 200 ms after the last spike
        delete_range = np.arange(V_old_ind, V_max_last_200+1,1)  ## delete from max. of old spike to the 200 ms after the max. of the last spike
        experiment_array = np.delete(experiment_array, delete_range,1)   
        V_maxes_ind = np.append(V_maxes_ind, V_old_ind)          ## since the index of current spike is changed, store the new index
        V_s_index = np.argmax(experiment_array[2,:] > V_s)
        V_s_plus = (np.argmax(experiment_array[0][V_s_index:(V_s_index+100)]))
        V_max_array_ind = int(V_s_index+V_s_plus)        
        not_keeping_next = 0                                     ## go back to 0 since this 200 ms interval is completed
        print("This is the "+str(spike)+"th spike. Finally filtered.")
        spike += 1
    elif V_last_spike + 200 < V_s and not_keeping_next ==0:      ## there aren't any extra spikes in the 200 ms period, filter directly
        V_max_last_200 = (V_max_last_ind+int(200/dt))    
        delete_range = np.arange(V_max_last_ind, V_max_last_200+1,1) 
        experiment_array = np.delete(experiment_array, delete_range,1) 
        V_maxes_ind = np.append(V_maxes_ind, V_max_last_ind)
        V_s_index = np.argmax(experiment_array[2,:] > V_s)
        V_s_plus = (np.argmax(experiment_array[0][V_s_index:(V_s_index+100)]))
        V_max_array_ind = int(V_s_index+V_s_plus) 
        print("This is the "+str(spike)+"th spike. Filtered.")
        spike += 1
    V_max_last_ind = V_max_array_ind                             ## always store the last spike since it can be used in the next filtering
    V_last_spike = V_s
if not_keeping_next==1:                                          ## sometimes there are a lot of spike in the very last 200 ms 
    V_max_last_200 = (V_max_last_ind+int(200/dt))                ## and loop is completed without them filtered, these lines are to filter them if this is the case 
    delete_range = np.arange(V_old_ind, V_max_last_200+1,1)
    experiment_array = np.delete(experiment_array, delete_range,1) 
    print("This is the last spike. Filtering is completed.")
# Out:
# This is the 1th spike. We will skip that.
# This is the 2th spike. We will skip that.
# This is the 3th spike. Finally filtered.
# This is the 4th spike. Filtered.
# This is the 5th spike. We will skip that.
# This is the 6th spike. We will skip that.
# This is the 7th spike. Finally filtered.
# This is the 8th spike. Filtered.
# This is the 9th spike. Filtered.
# This is the 10th spike. Filtered.
# This is the 11th spike. Filtered.
# This is the 12th spike. We will skip that.
# This is the 13th spike. Finally filtered.
# This is the 14th spike. We will skip that.
# This is the 15th spike. We will skip that.
# This is the 16th spike. We will skip that.
# This is the 17th spike. Finally filtered.
# This is the 18th spike. We will skip that.
# This is the 19th spike. We will skip that.
# This is the 20th spike. Finally filtered.
# This is the 21th spike. Filtered.
# This is the 22th spike. Filtered.
# This is the 23th spike. We will skip that.
# This is the 24th spike. We will skip that.
# This is the 25th spike. We will skip that.
# This is the 26th spike. Finally filtered.
# This is the 27th spike. Filtered.
# This is the 28th spike. We will skip that.
# This is the 29th spike. We will skip that.
# This is the 30th spike. Finally filtered.
# This is the 31th spike. We will skip that.
# This is the 32th spike. Finally filtered.
# This is the 33th spike. We will skip that.
# This is the 34th spike. We will skip that.
# This is the 35th spike. We will skip that.
# This is the 36th spike. Finally filtered.
# This is the 37th spike. We will skip that.
# This is the 38th spike. Finally filtered.
# This is the 39th spike. We will skip that.
# This is the 40th spike. Finally filtered.
# This is the 41th spike. Filtered.
# This is the 42th spike. We will skip that.
# This is the 43th spike. We will skip that.
# This is the 44th spike. We will skip that.
# This is the 45th spike. Finally filtered.
# This is the 46th spike. Filtered.
# This is the 47th spike. Filtered.
# This is the 48th spike. We will skip that.
# This is the 49th spike. We will skip that.
# This is the 50th spike. Finally filtered.
# This is the 51th spike. We will skip that.
# This is the 52th spike. We will skip that.
# This is the 53th spike. We will skip that.
# This is the 54th spike. We will skip that.
# This is the 55th spike. We will skip that.
# This is the 56th spike. Finally filtered.
# This is the 57th spike. We will skip that.
# This is the 58th spike. Finally filtered.
# This is the 59th spike. Filtered.
# This is the 60th spike. We will skip that.
# This is the 61th spike. We will skip that.
# This is the 62th spike. Finally filtered.
# This is the 63th spike. Filtered.
# This is the 64th spike. We will skip that.
# This is the 65th spike. We will skip that.
# This is the 66th spike. Finally filtered.
# This is the 67th spike. Filtered.
# This is the 68th spike. Filtered.
# This is the 69th spike. We will skip that.
# This is the 70th spike. We will skip that.
# This is the 71th spike. Finally filtered.
# This is the 72th spike. Filtered.
# This is the 73th spike. We will skip that.
# This is the 74th spike. We will skip that.
# This is the 75th spike. We will skip that.
# This is the 76th spike. Finally filtered.
# This is the 77th spike. We will skip that.
# This is the 78th spike. Finally filtered.
# This is the 79th spike. Filtered.
# This is the 80th spike. We will skip that.
# This is the 81th spike. We will skip that.
# This is the 82th spike. Finally filtered.
# This is the 83th spike. Filtered.
# This is the 84th spike. We will skip that.
# This is the 85th spike. Finally filtered.
# This is the 86th spike. Filtered.
# This is the 87th spike. Filtered.
# This is the 88th spike. We will skip that.
# This is the 89th spike. Finally filtered.
# This is the 90th spike. We will skip that.
# This is the 91th spike. Finally filtered.
# This is the 92th spike. Filtered.
# This is the 93th spike. We will skip that.
# This is the 94th spike. We will skip that.
# This is the 95th spike. Finally filtered.
# This is the 96th spike. We will skip that.
# This is the 97th spike. Finally filtered.
# This is the 98th spike. Filtered.
# This is the 99th spike. We will skip that.
# This is the 100th spike. We will skip that.
# This is the 101th spike. Finally filtered.
# This is the 102th spike. We will skip that.
# This is the 103th spike. We will skip that.
# This is the 104th spike. We will skip that.
# This is the 105th spike. We will skip that.
# This is the 106th spike. Finally filtered.
# This is the 107th spike. Filtered.
# This is the 108th spike. Filtered.
# This is the 109th spike. Filtered.
# This is the 110th spike. We will skip that.
# This is the 111th spike. Finally filtered.
# This is the 112th spike. We will skip that.
# This is the 113th spike. Finally filtered.
# This is the 114th spike. We will skip that.
# This is the 115th spike. Finally filtered.
# This is the 116th spike. Filtered.
# This is the 117th spike. Filtered.
# This is the 118th spike. Filtered.
# This is the 119th spike. We will skip that.
# This is the 120th spike. We will skip that.
# This is the 121th spike. Finally filtered.
# This is the 122th spike. Filtered.
# This is the 123th spike. We will skip that.
# This is the 124th spike. We will skip that.
# This is the 125th spike. We will skip that.
# This is the 126th spike. We will skip that.
# This is the 127th spike. Finally filtered.
# This is the 128th spike. We will skip that.
# This is the 129th spike. We will skip that.
# This is the 130th spike. Finally filtered.
# This is the 131th spike. Filtered.
# This is the 132th spike. Filtered.
# This is the 133th spike. We will skip that.
# This is the 134th spike. Finally filtered.
# This is the 135th spike. Filtered.
# This is the 136th spike. We will skip that.
# This is the 137th spike. Finally filtered.
# This is the 138th spike. Filtered.
# This is the 139th spike. We will skip that.
# This is the 140th spike. We will skip that.
# This is the 141th spike. Finally filtered.
# This is the 142th spike. We will skip that.
# This is the 143th spike. We will skip that.
# This is the 144th spike. We will skip that.
# This is the 145th spike. Finally filtered.
# This is the 146th spike. We will skip that.
# This is the 147th spike. We will skip that.
# This is the 148th spike. We will skip that.
# This is the 149th spike. Finally filtered.
# This is the 150th spike. Filtered.
# This is the 151th spike. Filtered.
# This is the 152th spike. We will skip that.
# This is the 153th spike. Finally filtered.
# This is the 154th spike. Filtered.
# This is the 155th spike. We will skip that.
# This is the 156th spike. Finally filtered.
# This is the 157th spike. We will skip that.
# This is the 158th spike. Finally filtered.
# This is the 159th spike. We will skip that.
# This is the 160th spike. We will skip that.
# This is the 161th spike. Finally filtered.
# This is the 162th spike. We will skip that.
# This is the 163th spike. We will skip that.
# This is the 164th spike. Finally filtered.
# This is the 165th spike. Filtered.
# This is the 166th spike. We will skip that.
# This is the 167th spike. Finally filtered.
# This is the 168th spike. We will skip that.
# This is the 169th spike. Finally filtered.
# This is the 170th spike. Filtered.
# This is the 171th spike. We will skip that.
# This is the 172th spike. Finally filtered.
# This is the 173th spike. We will skip that.
# This is the 174th spike. Finally filtered.
# This is the 175th spike. We will skip that.
# This is the 176th spike. Finally filtered.
# This is the 177th spike. Filtered.
# This is the 178th spike. We will skip that.
# This is the 179th spike. We will skip that.
# This is the 180th spike. We will skip that.
# This is the 181th spike. Finally filtered.
# This is the 182th spike. Filtered.
# This is the 183th spike. We will skip that.
# This is the 184th spike. Finally filtered.
# This is the 185th spike. We will skip that.
# This is the 186th spike. We will skip that.
# This is the 187th spike. Finally filtered.
# This is the 188th spike. We will skip that.
# This is the 189th spike. We will skip that.
# This is the 190th spike. Finally filtered.
# This is the 191th spike. We will skip that.
# This is the 192th spike. We will skip that.
# This is the 193th spike. Finally filtered.
# This is the 194th spike. Filtered.
# This is the 195th spike. Filtered.
# This is the 196th spike. We will skip that.
# This is the 197th spike. We will skip that.
# This is the 198th spike. Finally filtered.
# This is the 199th spike. We will skip that.
# This is the 200th spike. We will skip that.
# This is the 201th spike. We will skip that.
# This is the 202th spike. We will skip that.
# This is the 203th spike. We will skip that.
# This is the 204th spike. Finally filtered.
# This is the 205th spike. Filtered.
# This is the 206th spike. We will skip that.
# This is the 207th spike. We will skip that.
# This is the 208th spike. We will skip that.
# This is the 209th spike. Finally filtered.
# This is the 210th spike. Filtered.
# This is the 211th spike. We will skip that.
# This is the 212th spike. We will skip that.
# This is the 213th spike. We will skip that.
# This is the 214th spike. We will skip that.
# This is the 215th spike. We will skip that.
# This is the 216th spike. We will skip that.
# This is the 217th spike. We will skip that.
# This is the 218th spike. Finally filtered.
# This is the 219th spike. We will skip that.
# This is the 220th spike. We will skip that.
# This is the 221th spike. We will skip that.
# This is the 222th spike. We will skip that.
# This is the 223th spike. We will skip that.
# This is the 224th spike. We will skip that.
# This is the 225th spike. Finally filtered.
# This is the 226th spike. We will skip that.
# This is the 227th spike. Finally filtered.
# This is the 228th spike. We will skip that.
# This is the 229th spike. Finally filtered.
# This is the 230th spike. Filtered.
# This is the 231th spike. We will skip that.
# This is the 232th spike. We will skip that.
# This is the 233th spike. We will skip that.
# This is the 234th spike. We will skip that.
# This is the 235th spike. We will skip that.
# This is the 236th spike. We will skip that.
# This is the 237th spike. We will skip that.
# This is the 238th spike. We will skip that.
# This is the 239th spike. Finally filtered.
# This is the 240th spike. We will skip that.
# This is the 241th spike. Finally filtered.
# This is the 242th spike. We will skip that.
# This is the 243th spike. Finally filtered.
# This is the 244th spike. Filtered.
# This is the 245th spike. We will skip that.
# This is the 246th spike. We will skip that.
# This is the 247th spike. We will skip that.
# This is the 248th spike. Finally filtered.
# This is the 249th spike. Filtered.
# This is the 250th spike. We will skip that.
# This is the 251th spike. We will skip that.
# This is the 252th spike. We will skip that.
# This is the 253th spike. Finally filtered.
# This is the 254th spike. Filtered.
# This is the 255th spike. Filtered.
# This is the 256th spike. Filtered.
# This is the 257th spike. We will skip that.
# This is the 258th spike. We will skip that.
# This is the 259th spike. We will skip that.
# This is the 260th spike. We will skip that.
# This is the 261th spike. We will skip that.
# This is the 262th spike. Finally filtered.
# This is the 263th spike. We will skip that.
# This is the 264th spike. We will skip that.
# This is the 265th spike. Finally filtered.
# This is the 266th spike. We will skip that.
# This is the 267th spike. We will skip that.
# This is the 268th spike. We will skip that.
# This is the 269th spike. We will skip that.
# This is the 270th spike. Finally filtered.
# This is the 271th spike. Filtered.
# This is the 272th spike. We will skip that.
# This is the 273th spike. We will skip that.
# This is the 274th spike. Finally filtered.
# This is the 275th spike. We will skip that.
# This is the 276th spike. We will skip that.
# This is the 277th spike. We will skip that.
# This is the 278th spike. Finally filtered.
# This is the 279th spike. We will skip that.
# This is the 280th spike. We will skip that.
# This is the 281th spike. Finally filtered.
# This is the 282th spike. We will skip that.
# This is the 283th spike. Finally filtered.
# This is the 284th spike. We will skip that.
# This is the 285th spike. We will skip that.
# This is the 286th spike. We will skip that.
# This is the 287th spike. Finally filtered.
# This is the 288th spike. We will skip that.
# This is the 289th spike. We will skip that.
# This is the 290th spike. We will skip that.
# This is the 291th spike. We will skip that.
# This is the 292th spike. We will skip that.
# This is the 293th spike. Finally filtered.
# This is the 294th spike. Filtered.
# This is the 295th spike. We will skip that.
# This is the 296th spike. We will skip that.
# This is the 297th spike. We will skip that.
# This is the 298th spike. We will skip that.
# This is the 299th spike. We will skip that.
# This is the 300th spike. We will skip that.
# This is the 301th spike. We will skip that.
# This is the 302th spike. We will skip that.
# This is the 303th spike. We will skip that.
# This is the 304th spike. We will skip that.
# This is the 305th spike. We will skip that.
# This is the 306th spike. We will skip that.
# This is the 307th spike. We will skip that.
# This is the 308th spike. We will skip that.
# This is the 309th spike. We will skip that.
# This is the 310th spike. We will skip that.
# This is the 311th spike. We will skip that.
# This is the 312th spike. Finally filtered.
# This is the 313th spike. We will skip that.
# This is the 314th spike. We will skip that.
# This is the 315th spike. We will skip that.
# This is the 316th spike. Finally filtered.
# This is the 317th spike. We will skip that.
# This is the 318th spike. Finally filtered.
# This is the 319th spike. We will skip that.
# This is the 320th spike. We will skip that.
# This is the 321th spike. Finally filtered.
# This is the 322th spike. Filtered.
# This is the 323th spike. Filtered.
# This is the 324th spike. We will skip that.
# This is the 325th spike. We will skip that.
# This is the 326th spike. We will skip that.
# This is the 327th spike. Finally filtered.
# This is the 328th spike. Filtered.
# This is the 329th spike. We will skip that.
# This is the 330th spike. Finally filtered.
# This is the 331th spike. We will skip that.
# This is the 332th spike. We will skip that.
# This is the 333th spike. We will skip that.
# This is the 334th spike. We will skip that.
# This is the 335th spike. Finally filtered.
# This is the 336th spike. We will skip that.
# This is the 337th spike. We will skip that.
# This is the 338th spike. We will skip that.
# This is the 339th spike. We will skip that.
# This is the 340th spike. We will skip that.
# This is the 341th spike. Finally filtered.
# This is the 342th spike. Filtered.
# This is the 343th spike. Filtered.
# This is the 344th spike. We will skip that.
# This is the 345th spike. We will skip that.
# This is the 346th spike. We will skip that.
# This is the 347th spike. We will skip that.
# This is the 348th spike. Finally filtered.
# This is the 349th spike. We will skip that.
# This is the 350th spike. We will skip that.
# This is the 351th spike. Finally filtered.
# This is the 352th spike. We will skip that.
# This is the 353th spike. Finally filtered.
# This is the 354th spike. Filtered.
# This is the 355th spike. We will skip that.
# This is the 356th spike. Finally filtered.
# This is the 357th spike. Filtered.
# This is the 358th spike. We will skip that.
# This is the 359th spike. We will skip that.
# This is the 360th spike. We will skip that.
# This is the 361th spike. We will skip that.
# This is the 362th spike. Finally filtered.
# This is the 363th spike. We will skip that.
# This is the 364th spike. We will skip that.
# This is the 365th spike. We will skip that.
# This is the 366th spike. Finally filtered.
# This is the 367th spike. We will skip that.
# This is the 368th spike. Finally filtered.
# This is the 369th spike. Filtered.
# This is the 370th spike. We will skip that.
# This is the 371th spike. We will skip that.
# This is the 372th spike. We will skip that.
# This is the 373th spike. Finally filtered.
# This is the 374th spike. We will skip that.
# This is the 375th spike. We will skip that.
# This is the 376th spike. We will skip that.
# This is the 377th spike. We will skip that.
# This is the 378th spike. Finally filtered.
# This is the 379th spike. We will skip that.
# This is the 380th spike. We will skip that.
# This is the 381th spike. Finally filtered.
# This is the 382th spike. We will skip that.
# This is the 383th spike. Finally filtered.
# This is the 384th spike. Filtered.
# This is the 385th spike. We will skip that.
# This is the 386th spike. We will skip that.
# This is the 387th spike. We will skip that.
# This is the 388th spike. We will skip that.
# This is the 389th spike. We will skip that.
# This is the 390th spike. We will skip that.
# This is the 391th spike. We will skip that.
# This is the 392th spike. Finally filtered.
# This is the 393th spike. Filtered.
# This is the 394th spike. We will skip that.
# This is the 395th spike. We will skip that.
# This is the 396th spike. We will skip that.
# This is the 397th spike. We will skip that.
# This is the 398th spike. Finally filtered.
# This is the 399th spike. We will skip that.
# This is the 400th spike. We will skip that.
# This is the 401th spike. Finally filtered.
# This is the 402th spike. Filtered.
# This is the 403th spike. We will skip that.
# This is the 404th spike. We will skip that.
# This is the 405th spike. We will skip that.
# This is the 406th spike. We will skip that.
# This is the 407th spike. Finally filtered.
# This is the 408th spike. We will skip that.
# This is the 409th spike. Finally filtered.
# This is the 410th spike. We will skip that.
# This is the 411th spike. We will skip that.
# This is the 412th spike. Finally filtered.
# This is the 413th spike. We will skip that.
# This is the 414th spike. We will skip that.
# This is the 415th spike. We will skip that.
# This is the 416th spike. We will skip that.
# This is the 417th spike. We will skip that.
# This is the 418th spike. Finally filtered.
# This is the 419th spike. We will skip that.
# This is the 420th spike. We will skip that.
# This is the 421th spike. We will skip that.
# This is the 422th spike. We will skip that.
# This is the 423th spike. Finally filtered.
# This is the 424th spike. We will skip that.
# This is the 425th spike. We will skip that.
# This is the 426th spike. We will skip that.
# This is the 427th spike. We will skip that.
# This is the 428th spike. We will skip that.
# This is the 429th spike. Finally filtered.
# This is the 430th spike. We will skip that.
# This is the 431th spike. Finally filtered.
# This is the 432th spike. We will skip that.
# This is the 433th spike. We will skip that.
# This is the 434th spike. Finally filtered.
# This is the 435th spike. We will skip that.
# This is the 436th spike. We will skip that.
# This is the 437th spike. We will skip that.
# This is the 438th spike. Finally filtered.
# This is the 439th spike. We will skip that.
# This is the 440th spike. We will skip that.
# This is the 441th spike. Finally filtered.
# This is the 442th spike. We will skip that.
# This is the 443th spike. We will skip that.
# This is the 444th spike. We will skip that.
# This is the 445th spike. We will skip that.
# This is the 446th spike. We will skip that.
# This is the 447th spike. We will skip that.
# This is the 448th spike. We will skip that.
# This is the 449th spike. We will skip that.
# This is the 450th spike. We will skip that.
# This is the 451th spike. We will skip that.
# This is the 452th spike. We will skip that.
# This is the 453th spike. Finally filtered.
# This is the 454th spike. We will skip that.
# This is the 455th spike. We will skip that.
# This is the 456th spike. We will skip that.
# This is the 457th spike. We will skip that.
# This is the 458th spike. We will skip that.
# This is the 459th spike. We will skip that.
# This is the 460th spike. We will skip that.
# This is the 461th spike. Finally filtered.
# This is the 462th spike. We will skip that.
# This is the 463th spike. We will skip that.
# This is the 464th spike. We will skip that.
# This is the 465th spike. Finally filtered.
# This is the 466th spike. We will skip that.
# This is the 467th spike. We will skip that.
# This is the 468th spike. We will skip that.
# This is the 469th spike. We will skip that.
# This is the 470th spike. We will skip that.
# This is the 471th spike. We will skip that.
# This is the 472th spike. Finally filtered.
# This is the 473th spike. We will skip that.
# This is the 474th spike. We will skip that.
# This is the 475th spike. We will skip that.
# This is the 476th spike. We will skip that.
# This is the 477th spike. We will skip that.
# This is the 478th spike. We will skip that.
# This is the 479th spike. Finally filtered.
# This is the 480th spike. We will skip that.
# This is the 481th spike. We will skip that.
# This is the 482th spike. We will skip that.
# This is the 483th spike. We will skip that.
# This is the 484th spike. We will skip that.
# This is the 485th spike. Finally filtered.
# This is the 486th spike. We will skip that.
# This is the 487th spike. We will skip that.
# This is the 488th spike. We will skip that.
# This is the 489th spike. We will skip that.
# This is the 490th spike. We will skip that.
# This is the 491th spike. We will skip that.
# This is the 492th spike. Finally filtered.
# This is the 493th spike. We will skip that.
# This is the 494th spike. We will skip that.
# This is the 495th spike. We will skip that.
# This is the 496th spike. We will skip that.
# This is the 497th spike. We will skip that.
# This is the 498th spike. Finally filtered.
# This is the 499th spike. We will skip that.
# This is the 500th spike. We will skip that.
# This is the 501th spike. We will skip that.
# This is the 502th spike. Finally filtered.
# This is the 503th spike. We will skip that.
# This is the 504th spike. We will skip that.
# This is the 505th spike. Finally filtered.
# This is the 506th spike. We will skip that.
# This is the 507th spike. Finally filtered.
# This is the 508th spike. We will skip that.
# This is the 509th spike. We will skip that.
# This is the 510th spike. We will skip that.
# This is the 511th spike. We will skip that.
# This is the 512th spike. We will skip that.
# This is the 513th spike. We will skip that.
# This is the 514th spike. We will skip that.
# This is the 515th spike. We will skip that.
# This is the 516th spike. We will skip that.
# This is the 517th spike. Finally filtered.
# This is the 518th spike. Filtered.
# This is the 519th spike. We will skip that.
# This is the 520th spike. We will skip that.
# This is the 521th spike. We will skip that.
# This is the 522th spike. Finally filtered.
# This is the 523th spike. We will skip that.
# This is the 524th spike. We will skip that.
# This is the 525th spike. Finally filtered.
# This is the 526th spike. We will skip that.
# This is the 527th spike. Finally filtered.
# This is the 528th spike. We will skip that.
# This is the 529th spike. We will skip that.
# This is the 530th spike. Finally filtered.
# This is the 531th spike. We will skip that.
# This is the 532th spike. We will skip that.
# This is the 533th spike. Finally filtered.
# This is the 534th spike. We will skip that.
# This is the 535th spike. Finally filtered.
# This is the 536th spike. We will skip that.
# This is the 537th spike. We will skip that.
# This is the 538th spike. We will skip that.
# This is the 539th spike. We will skip that.
# This is the 540th spike. Finally filtered.
# This is the 541th spike. We will skip that.
# This is the 542th spike. We will skip that.
# This is the 543th spike. We will skip that.
# This is the 544th spike. Finally filtered.
# This is the 545th spike. We will skip that.
# This is the 546th spike. We will skip that.
# This is the 547th spike. We will skip that.
# This is the 548th spike. We will skip that.
# This is the 549th spike. We will skip that.
# This is the 550th spike. We will skip that.
# This is the 551th spike. Finally filtered.
# This is the 552th spike. Filtered.
# This is the 553th spike. We will skip that.
# This is the 554th spike. We will skip that.
# This is the 555th spike. We will skip that.
# This is the 556th spike. We will skip that.
# This is the 557th spike. We will skip that.
# This is the 558th spike. We will skip that.
# This is the 559th spike. We will skip that.
# This is the 560th spike. We will skip that.
# This is the 561th spike. We will skip that.
# This is the 562th spike. We will skip that.
# This is the 563th spike. We will skip that.
# This is the 564th spike. We will skip that.
# This is the 565th spike. We will skip that.
# This is the 566th spike. We will skip that.
# This is the 567th spike. Finally filtered.
# This is the 568th spike. We will skip that.
# This is the 569th spike. We will skip that.
# This is the 570th spike. Finally filtered.
# This is the 571th spike. Filtered.
# This is the 572th spike. We will skip that.
# This is the 573th spike. We will skip that.
# This is the 574th spike. We will skip that.
# This is the 575th spike. We will skip that.
# This is the 576th spike. We will skip that.
# This is the 577th spike. We will skip that.
# This is the 578th spike. We will skip that.
# This is the 579th spike. We will skip that.
# This is the 580th spike. We will skip that.
# This is the 581th spike. We will skip that.
# This is the 582th spike. Finally filtered.
# This is the 583th spike. Filtered.
# This is the 584th spike. We will skip that.
# This is the 585th spike. We will skip that.
# This is the 586th spike. Finally filtered.
# This is the 587th spike. We will skip that.
# This is the 588th spike. We will skip that.
# This is the 589th spike. Finally filtered.
# This is the 590th spike. We will skip that.
# This is the 591th spike. We will skip that.
# This is the 592th spike. We will skip that.
# This is the 593th spike. Finally filtered.
# This is the 594th spike. We will skip that.
# This is the 595th spike. We will skip that.
# This is the 596th spike. We will skip that.
# This is the 597th spike. We will skip that.
# This is the 598th spike. Finally filtered.
# This is the 599th spike. We will skip that.
# This is the 600th spike. We will skip that.
# This is the 601th spike. We will skip that.
# This is the 602th spike. We will skip that.
# This is the 603th spike. We will skip that.
# This is the 604th spike. We will skip that.
# This is the 605th spike. We will skip that.
# This is the 606th spike. Finally filtered.
# This is the 607th spike. We will skip that.
# This is the 608th spike. We will skip that.
# This is the 609th spike. Finally filtered.
# This is the 610th spike. We will skip that.
# This is the 611th spike. We will skip that.
# This is the 612th spike. We will skip that.
# This is the 613th spike. We will skip that.
# This is the 614th spike. We will skip that.
# This is the 615th spike. We will skip that.
# This is the 616th spike. We will skip that.
# This is the 617th spike. Finally filtered.
# This is the 618th spike. Filtered.
# This is the 619th spike. We will skip that.
# This is the 620th spike. We will skip that.
# This is the 621th spike. We will skip that.
# This is the 622th spike. We will skip that.
# This is the 623th spike. We will skip that.
# This is the 624th spike. We will skip that.
# This is the 625th spike. We will skip that.
# This is the 626th spike. We will skip that.
# This is the 627th spike. We will skip that.
# This is the 628th spike. Finally filtered.
# This is the 629th spike. We will skip that.
# This is the 630th spike. We will skip that.
# This is the 631th spike. We will skip that.
# This is the 632th spike. We will skip that.
# This is the 633th spike. Finally filtered.
# This is the 634th spike. We will skip that.
# This is the 635th spike. We will skip that.
# This is the 636th spike. We will skip that.
# This is the 637th spike. We will skip that.
# This is the 638th spike. We will skip that.
# This is the 639th spike. We will skip that.
# This is the 640th spike. We will skip that.
# This is the 641th spike. Finally filtered.
# This is the 642th spike. Filtered.
# This is the 643th spike. We will skip that.
# This is the 644th spike. Finally filtered.
# This is the 645th spike. Filtered.
# This is the 646th spike. Filtered.
# This is the 647th spike. We will skip that.
# This is the 648th spike. We will skip that.
# This is the 649th spike. Finally filtered.
# This is the 650th spike. We will skip that.
# This is the 651th spike. Finally filtered.
# This is the 652th spike. We will skip that.
# This is the 653th spike. Finally filtered.
# This is the 654th spike. Filtered.
# This is the 655th spike. Filtered.
# This is the 656th spike. We will skip that.
# This is the 657th spike. We will skip that.
# This is the 658th spike. Finally filtered.
# This is the 659th spike. Filtered.
# This is the 660th spike. We will skip that.
# This is the 661th spike. Finally filtered.
# This is the 662th spike. We will skip that.
# This is the 663th spike. We will skip that.
# This is the 664th spike. We will skip that.
# This is the 665th spike. We will skip that.
# This is the 666th spike. Finally filtered.
# This is the 667th spike. Filtered.
# This is the 668th spike. We will skip that.
# This is the 669th spike. We will skip that.
# This is the 670th spike. We will skip that.
# This is the 671th spike. Finally filtered.
# This is the 672th spike. We will skip that.
# This is the 673th spike. We will skip that.
# This is the 674th spike. We will skip that.
# This is the 675th spike. We will skip that.
# This is the 676th spike. We will skip that.
# This is the 677th spike. We will skip that.
# This is the 678th spike. We will skip that.
# This is the 679th spike. We will skip that.
# This is the 680th spike. We will skip that.
# This is the 681th spike. We will skip that.
# This is the 682th spike. We will skip that.
# This is the 683th spike. We will skip that.
# This is the 684th spike. Finally filtered.
# This is the 685th spike. Filtered.
# This is the 686th spike. We will skip that.
# This is the 687th spike. Finally filtered.
# This is the 688th spike. Filtered.
# This is the 689th spike. We will skip that.
# This is the 690th spike. We will skip that.
# This is the 691th spike. We will skip that.
# This is the 692th spike. Finally filtered.
# This is the 693th spike. We will skip that.
# This is the 694th spike. We will skip that.
# This is the 695th spike. Finally filtered.
# This is the 696th spike. Filtered.
# This is the 697th spike. We will skip that.
# This is the 698th spike. We will skip that.
# This is the 699th spike. We will skip that.
# This is the 700th spike. We will skip that.
# This is the 701th spike. We will skip that.
# This is the 702th spike. We will skip that.
# This is the 703th spike. We will skip that.
# This is the 704th spike. We will skip that.
# This is the 705th spike. We will skip that.
# This is the 706th spike. Finally filtered.
# This is the 707th spike. Filtered.
# This is the 708th spike. Filtered.
# This is the 709th spike. We will skip that.
# This is the 710th spike. Finally filtered.
# This is the 711th spike. We will skip that.
# This is the 712th spike. Finally filtered.
# This is the 713th spike. We will skip that.
# This is the 714th spike. We will skip that.
# This is the 715th spike. We will skip that.
# This is the 716th spike. Finally filtered.
# This is the 717th spike. We will skip that.
# This is the 718th spike. We will skip that.
# This is the 719th spike. We will skip that.
# This is the 720th spike. We will skip that.
# This is the 721th spike. We will skip that.
# This is the 722th spike. We will skip that.
# This is the 723th spike. We will skip that.
# This is the 724th spike. We will skip that.
# This is the 725th spike. Finally filtered.
# This is the 726th spike. We will skip that.
# This is the 727th spike. We will skip that.
# This is the 728th spike. We will skip that.
# This is the 729th spike. Finally filtered.
# This is the 730th spike. We will skip that.
# This is the 731th spike. We will skip that.
# This is the 732th spike. We will skip that.
# This is the 733th spike. We will skip that.
# This is the 734th spike. We will skip that.
# This is the 735th spike. Finally filtered.
# This is the 736th spike. We will skip that.
# This is the 737th spike. We will skip that.
# This is the 738th spike. We will skip that.
# This is the 739th spike. We will skip that.
# This is the 740th spike. We will skip that.
# This is the 741th spike. We will skip that.
# This is the 742th spike. Finally filtered.
# This is the 743th spike. We will skip that.
# This is the 744th spike. We will skip that.
# This is the 745th spike. We will skip that.
# This is the 746th spike. We will skip that.
# This is the 747th spike. We will skip that.
# This is the 748th spike. We will skip that.
# This is the 749th spike. We will skip that.
# This is the 750th spike. We will skip that.
# This is the 751th spike. We will skip that.
# This is the 752th spike. We will skip that.
# This is the 753th spike. We will skip that.
# This is the 754th spike. We will skip that.
# This is the 755th spike. We will skip that.
# This is the 756th spike. We will skip that.
# This is the 757th spike. We will skip that.
# This is the 758th spike. We will skip that.
# This is the 759th spike. We will skip that.
# This is the 760th spike. Finally filtered.
# This is the 761th spike. We will skip that.
# This is the 762th spike. We will skip that.
# This is the 763th spike. We will skip that.
# This is the 764th spike. Finally filtered.
# This is the 765th spike. We will skip that.
# This is the 766th spike. We will skip that.
# This is the 767th spike. We will skip that.
# This is the 768th spike. We will skip that.
# This is the 769th spike. We will skip that.
# This is the 770th spike. Finally filtered.
# This is the 771th spike. Filtered.
# This is the 772th spike. Filtered.
# This is the 773th spike. We will skip that.
# This is the 774th spike. We will skip that.
# This is the 775th spike. We will skip that.
# This is the 776th spike. Finally filtered.
# This is the 777th spike. We will skip that.
# This is the 778th spike. We will skip that.
# This is the 779th spike. We will skip that.
# This is the 780th spike. We will skip that.
# This is the 781th spike. We will skip that.
# This is the 782th spike. We will skip that.
# This is the 783th spike. We will skip that.
# This is the 784th spike. We will skip that.
# This is the 785th spike. We will skip that.
# This is the 786th spike. Finally filtered.
# This is the 787th spike. We will skip that.
# This is the 788th spike. We will skip that.
# This is the 789th spike. We will skip that.
# This is the 790th spike. Finally filtered.
# This is the 791th spike. We will skip that.
# This is the 792th spike. We will skip that.
# This is the 793th spike. We will skip that.
# This is the 794th spike. We will skip that.
# This is the 795th spike. We will skip that.
# This is the 796th spike. We will skip that.
# This is the 797th spike. We will skip that.
# This is the 798th spike. Finally filtered.
# This is the 799th spike. We will skip that.
# This is the 800th spike. We will skip that.
# This is the 801th spike. We will skip that.
# This is the 802th spike. We will skip that.
# This is the 803th spike. We will skip that.
# This is the 804th spike. We will skip that.
# This is the 805th spike. We will skip that.
# This is the 806th spike. We will skip that.
# This is the 807th spike. We will skip that.
# This is the 808th spike. We will skip that.
# This is the 809th spike. We will skip that.
# This is the 810th spike. We will skip that.
# This is the 811th spike. We will skip that.
# This is the 812th spike. We will skip that.
# This is the 813th spike. We will skip that.
# This is the 814th spike. We will skip that.
# This is the 815th spike. Finally filtered.
# This is the 816th spike. We will skip that.
# This is the 817th spike. Finally filtered.
# This is the 818th spike. We will skip that.
# This is the 819th spike. We will skip that.
# This is the 820th spike. We will skip that.
# This is the 821th spike. We will skip that.
# This is the 822th spike. We will skip that.
# This is the 823th spike. We will skip that.
# This is the 824th spike. We will skip that.
# This is the 825th spike. We will skip that.
# This is the 826th spike. We will skip that.
# This is the 827th spike. We will skip that.
# This is the 828th spike. We will skip that.
# This is the 829th spike. We will skip that.
# This is the 830th spike. We will skip that.
# This is the 831th spike. Finally filtered.
# This is the 832th spike. We will skip that.
# This is the 833th spike. We will skip that.
# This is the 834th spike. We will skip that.
# This is the 835th spike. We will skip that.
# This is the 836th spike. We will skip that.
# This is the 837th spike. We will skip that.
# This is the 838th spike. We will skip that.
# This is the 839th spike. We will skip that.
# This is the 840th spike. We will skip that.
# This is the 841th spike. We will skip that.
# This is the 842th spike. We will skip that.
# This is the 843th spike. We will skip that.
# This is the 844th spike. We will skip that.
# This is the 845th spike. We will skip that.
# This is the 846th spike. We will skip that.
# This is the 847th spike. We will skip that.
# This is the 848th spike. We will skip that.
# This is the 849th spike. We will skip that.
# This is the 850th spike. We will skip that.
# This is the 851th spike. We will skip that.
# This is the 852th spike. We will skip that.
# This is the 853th spike. We will skip that.
# This is the 854th spike. We will skip that.
# This is the 855th spike. We will skip that.
# This is the 856th spike. We will skip that.
# This is the 857th spike. We will skip that.
# This is the 858th spike. We will skip that.
# This is the 859th spike. We will skip that.
# This is the 860th spike. Finally filtered.
# This is the 861th spike. Filtered.
# This is the 862th spike. We will skip that.
# This is the 863th spike. We will skip that.
# This is the 864th spike. We will skip that.
# This is the 865th spike. We will skip that.
# This is the 866th spike. We will skip that.
# This is the 867th spike. We will skip that.
# This is the 868th spike. We will skip that.
# This is the 869th spike. We will skip that.
# This is the 870th spike. We will skip that.
# This is the 871th spike. We will skip that.
# This is the 872th spike. We will skip that.
# This is the 873th spike. We will skip that.
# This is the 874th spike. We will skip that.
# This is the 875th spike. We will skip that.
# This is the 876th spike. We will skip that.
# This is the 877th spike. We will skip that.
# This is the 878th spike. We will skip that.
# This is the 879th spike. Finally filtered.
# This is the 880th spike. We will skip that.
# This is the 881th spike. We will skip that.
# This is the 882th spike. We will skip that.
# This is the 883th spike. We will skip that.
# This is the 884th spike. We will skip that.
# This is the 885th spike. We will skip that.
# This is the 886th spike. We will skip that.
# This is the 887th spike. We will skip that.
# This is the 888th spike. We will skip that.
# This is the 889th spike. We will skip that.
# This is the 890th spike. We will skip that.
# This is the 891th spike. We will skip that.
# This is the 892th spike. We will skip that.
# This is the 893th spike. We will skip that.
# This is the 894th spike. We will skip that.
# This is the 895th spike. We will skip that.
# This is the 896th spike. We will skip that.
# This is the 897th spike. We will skip that.
# This is the 898th spike. We will skip that.
# This is the 899th spike. We will skip that.
# This is the 900th spike. We will skip that.
# This is the 901th spike. We will skip that.
# This is the 902th spike. We will skip that.
# This is the 903th spike. We will skip that.
# This is the 904th spike. We will skip that.
# This is the 905th spike. We will skip that.
# This is the 906th spike. We will skip that.
# This is the 907th spike. Finally filtered.
# This is the 908th spike. We will skip that.
# This is the 909th spike. We will skip that.
# This is the 910th spike. We will skip that.
# This is the 911th spike. We will skip that.
# This is the 912th spike. We will skip that.
# This is the 913th spike. We will skip that.
# This is the 914th spike. We will skip that.
# This is the 915th spike. We will skip that.
# This is the 916th spike. Finally filtered.
# This is the 917th spike. We will skip that.
# This is the 918th spike. We will skip that.
# This is the 919th spike. We will skip that.
# This is the 920th spike. We will skip that.
# This is the 921th spike. Finally filtered.
# This is the 922th spike. We will skip that.
# This is the 923th spike. We will skip that.
# This is the 924th spike. Finally filtered.
# This is the 925th spike. We will skip that.
# This is the 926th spike. We will skip that.
# This is the 927th spike. We will skip that.
# This is the 928th spike. We will skip that.
# This is the 929th spike. We will skip that.
# This is the 930th spike. We will skip that.
# This is the 931th spike. Finally filtered.
# This is the 932th spike. We will skip that.
# This is the 933th spike. We will skip that.
# This is the 934th spike. We will skip that.
# This is the 935th spike. We will skip that.
# This is the 936th spike. Finally filtered.
# This is the 937th spike. We will skip that.
# This is the 938th spike. Finally filtered.
# This is the 939th spike. We will skip that.
# This is the 940th spike. We will skip that.
# This is the 941th spike. We will skip that.
# This is the 942th spike. We will skip that.
# This is the 943th spike. We will skip that.
# This is the 944th spike. We will skip that.
# This is the 945th spike. We will skip that.
# This is the 946th spike. We will skip that.
# This is the 947th spike. We will skip that.
# This is the 948th spike. Finally filtered.
# This is the 949th spike. We will skip that.
# This is the 950th spike. We will skip that.
# This is the 951th spike. We will skip that.
# This is the 952th spike. We will skip that.
# This is the 953th spike. We will skip that.
# This is the 954th spike. We will skip that.
# This is the 955th spike. We will skip that.
# This is the 956th spike. We will skip that.
# This is the 957th spike. We will skip that.
# This is the 958th spike. We will skip that.
# This is the 959th spike. We will skip that.
# This is the 960th spike. We will skip that.
# This is the 961th spike. Finally filtered.
# This is the 962th spike. We will skip that.
# This is the 963th spike. We will skip that.
# This is the 964th spike. We will skip that.
# This is the 965th spike. We will skip that.
# This is the 966th spike. We will skip that.
# This is the 967th spike. We will skip that.
# This is the 968th spike. We will skip that.
# This is the 969th spike. We will skip that.
# This is the 970th spike. We will skip that.
# This is the 971th spike. We will skip that.
# This is the 972th spike. We will skip that.
# This is the 973th spike. We will skip that.
# This is the 974th spike. We will skip that.
# This is the 975th spike. We will skip that.
# This is the 976th spike. We will skip that.
# This is the 977th spike. We will skip that.
# This is the 978th spike. We will skip that.
# This is the 979th spike. We will skip that.
# This is the 980th spike. We will skip that.
# This is the 981th spike. We will skip that.
# This is the 982th spike. We will skip that.
# This is the 983th spike. We will skip that.
# This is the 984th spike. We will skip that.
# This is the 985th spike. We will skip that.
# This is the 986th spike. We will skip that.
# This is the 987th spike. We will skip that.
# This is the 988th spike. We will skip that.
# This is the 989th spike. We will skip that.
# This is the 990th spike. We will skip that.
# This is the 991th spike. We will skip that.
# This is the 992th spike. We will skip that.
# This is the 993th spike. We will skip that.
# This is the 994th spike. We will skip that.
# This is the 995th spike. We will skip that.
# This is the 996th spike. We will skip that.
# This is the 997th spike. We will skip that.
# This is the 998th spike. We will skip that.
# This is the 999th spike. We will skip that.
# This is the 1000th spike. We will skip that.
# This is the 1001th spike. We will skip that.
# This is the 1002th spike. We will skip that.
# This is the 1003th spike. Finally filtered.
# This is the 1004th spike. We will skip that.
# This is the 1005th spike. We will skip that.
# This is the 1006th spike. We will skip that.
# This is the 1007th spike. We will skip that.
# This is the 1008th spike. We will skip that.
# This is the 1009th spike. We will skip that.
# This is the 1010th spike. We will skip that.
# This is the 1011th spike. We will skip that.
# This is the 1012th spike. Finally filtered.
# This is the 1013th spike. We will skip that.
# This is the 1014th spike. We will skip that.
# This is the 1015th spike. We will skip that.
# This is the 1016th spike. We will skip that.
# This is the 1017th spike. We will skip that.
# This is the 1018th spike. We will skip that.
# This is the 1019th spike. We will skip that.
# This is the 1020th spike. We will skip that.
# This is the 1021th spike. We will skip that.
# This is the 1022th spike. We will skip that.
# This is the 1023th spike. We will skip that.
# This is the 1024th spike. We will skip that.
# This is the 1025th spike. We will skip that.
# This is the 1026th spike. We will skip that.
# This is the 1027th spike. We will skip that.
# This is the 1028th spike. We will skip that.
# This is the 1029th spike. Finally filtered.
# This is the 1030th spike. We will skip that.
# This is the 1031th spike. We will skip that.
# This is the 1032th spike. We will skip that.
# This is the 1033th spike. We will skip that.
# This is the 1034th spike. We will skip that.
# This is the 1035th spike. We will skip that.
# This is the 1036th spike. We will skip that.
# This is the 1037th spike. Finally filtered.
# This is the 1038th spike. We will skip that.
# This is the 1039th spike. We will skip that.
# This is the 1040th spike. Finally filtered.
# This is the 1041th spike. We will skip that.
# This is the 1042th spike. We will skip that.
# This is the 1043th spike. We will skip that.
# This is the 1044th spike. Finally filtered.
# This is the 1045th spike. We will skip that.
# This is the 1046th spike. We will skip that.
# This is the 1047th spike. We will skip that.
# This is the 1048th spike. Finally filtered.
# This is the 1049th spike. We will skip that.
# This is the 1050th spike. We will skip that.
# This is the 1051th spike. We will skip that.
# This is the 1052th spike. We will skip that.
# This is the 1053th spike. We will skip that.
# This is the 1054th spike. We will skip that.
# This is the 1055th spike. We will skip that.
# This is the 1056th spike. We will skip that.
# This is the 1057th spike. We will skip that.
# This is the 1058th spike. We will skip that.
# This is the 1059th spike. We will skip that.
# This is the 1060th spike. We will skip that.
# This is the 1061th spike. We will skip that.
# This is the 1062th spike. We will skip that.
# This is the 1063th spike. We will skip that.
# This is the 1064th spike. We will skip that.
# This is the 1065th spike. We will skip that.
# This is the 1066th spike. We will skip that.
# This is the 1067th spike. We will skip that.
# This is the 1068th spike. We will skip that.
# This is the 1069th spike. We will skip that.
# This is the 1070th spike. We will skip that.
# This is the 1071th spike. We will skip that.
# This is the 1072th spike. We will skip that.
# This is the 1073th spike. We will skip that.
# This is the 1074th spike. We will skip that.
# This is the 1075th spike. We will skip that.
# This is the 1076th spike. We will skip that.
# This is the 1077th spike. We will skip that.
# This is the 1078th spike. We will skip that.
# This is the 1079th spike. We will skip that.
# This is the 1080th spike. We will skip that.
# This is the 1081th spike. We will skip that.
# This is the 1082th spike. We will skip that.
# This is the 1083th spike. We will skip that.
# This is the 1084th spike. We will skip that.
# This is the 1085th spike. We will skip that.
# This is the 1086th spike. We will skip that.
# This is the 1087th spike. We will skip that.
# This is the 1088th spike. Finally filtered.
# This is the 1089th spike. We will skip that.
# This is the 1090th spike. We will skip that.
# This is the 1091th spike. We will skip that.
# This is the 1092th spike. We will skip that.
# This is the 1093th spike. We will skip that.
# This is the 1094th spike. We will skip that.
# This is the 1095th spike. We will skip that.
# This is the 1096th spike. We will skip that.
# This is the 1097th spike. We will skip that.
# This is the 1098th spike. We will skip that.
# This is the 1099th spike. We will skip that.
# This is the 1100th spike. We will skip that.
# This is the 1101th spike. We will skip that.
# This is the 1102th spike. We will skip that.
# This is the 1103th spike. We will skip that.
# This is the 1104th spike. We will skip that.
# This is the 1105th spike. We will skip that.
# This is the 1106th spike. We will skip that.
# This is the 1107th spike. Finally filtered.
# This is the 1108th spike. Filtered.
# This is the 1109th spike. We will skip that.
# This is the 1110th spike. We will skip that.
# This is the 1111th spike. We will skip that.
# This is the 1112th spike. We will skip that.
# ...
# This is the 2998th spike. We will skip that.
# This is the 2999th spike. We will skip that.
# This is the 3000th spike. We will skip that.
# This is the 3001th spike. We will skip that.
# This is the 3002th spike. We will skip that.
# This is the 3003th spike. We will skip that.
# This is the 3004th spike. We will skip that.
# This is the 3005th spike. We will skip that.
# This is the 3006th spike. We will skip that.
# This is the 3007th spike. We will skip that.
# This is the 3008th spike. We will skip that.
# This is the 3009th spike. We will skip that.
# This is the 3010th spike. We will skip that.
# This is the 3011th spike. We will skip that.
# This is the 3012th spike. We will skip that.
# This is the 3013th spike. We will skip that.
# This is the 3014th spike. We will skip that.
# This is the 3015th spike. We will skip that.
# This is the 3016th spike. We will skip that.
# This is the 3017th spike. We will skip that.
# This is the 3018th spike. We will skip that.
# This is the 3019th spike. We will skip that.
# This is the 3020th spike. We will skip that.
# This is the 3021th spike. We will skip that.
# This is the 3022th spike. We will skip that.
# This is the 3023th spike. We will skip that.
# This is the 3024th spike. We will skip that.
# This is the 3025th spike. We will skip that.
# This is the 3026th spike. We will skip that.
# This is the 3027th spike. We will skip that.
# This is the 3028th spike. We will skip that.
# This is the 3029th spike. We will skip that.
# This is the 3030th spike. We will skip that.
# This is the 3031th spike. We will skip that.
# This is the 3032th spike. We will skip that.
# This is the 3033th spike. We will skip that.
# This is the 3034th spike. We will skip that.
# This is the 3035th spike. We will skip that.
# This is the 3036th spike. We will skip that.
# This is the 3037th spike. We will skip that.
# This is the 3038th spike. We will skip that.
# This is the 3039th spike. We will skip that.
# This is the 3040th spike. We will skip that.
# This is the 3041th spike. We will skip that.
# This is the 3042th spike. We will skip that.
# This is the 3043th spike. We will skip that.
# This is the 3044th spike. We will skip that.
# This is the 3045th spike. We will skip that.
# This is the 3046th spike. Finally filtered.
# This is the 3047th spike. We will skip that.
# This is the 3048th spike. We will skip that.
# This is the 3049th spike. We will skip that.
# This is the 3050th spike. We will skip that.
# This is the 3051th spike. We will skip that.
# This is the 3052th spike. We will skip that.
# This is the 3053th spike. We will skip that.
# This is the 3054th spike. We will skip that.
# This is the 3055th spike. We will skip that.
# This is the 3056th spike. We will skip that.
# This is the 3057th spike. We will skip that.
# This is the 3058th spike. We will skip that.
# This is the 3059th spike. We will skip that.
# This is the 3060th spike. We will skip that.
# This is the 3061th spike. We will skip that.
# This is the 3062th spike. We will skip that.
# This is the 3063th spike. We will skip that.
# This is the 3064th spike. We will skip that.
# This is the 3065th spike. We will skip that.
# This is the 3066th spike. We will skip that.
# This is the 3067th spike. We will skip that.
# This is the 3068th spike. We will skip that.
# This is the 3069th spike. We will skip that.
# This is the 3070th spike. We will skip that.
# This is the 3071th spike. We will skip that.
# This is the 3072th spike. We will skip that.
# This is the 3073th spike. We will skip that.
# This is the 3074th spike. We will skip that.
# This is the 3075th spike. We will skip that.
# This is the 3076th spike. We will skip that.
# This is the 3077th spike. We will skip that.
# This is the 3078th spike. We will skip that.
# This is the 3079th spike. We will skip that.
# This is the 3080th spike. We will skip that.
# This is the 3081th spike. We will skip that.
# This is the 3082th spike. We will skip that.
# This is the 3083th spike. We will skip that.
# This is the 3084th spike. We will skip that.
# This is the 3085th spike. We will skip that.
# This is the 3086th spike. We will skip that.
# This is the 3087th spike. We will skip that.
# This is the 3088th spike. We will skip that.
# This is the 3089th spike. We will skip that.
# This is the 3090th spike. We will skip that.
# This is the 3091th spike. We will skip that.
# This is the 3092th spike. We will skip that.
# This is the 3093th spike. We will skip that.
# This is the 3094th spike. We will skip that.
# This is the 3095th spike. We will skip that.
# This is the 3096th spike. We will skip that.
# This is the 3097th spike. We will skip that.
# This is the 3098th spike. We will skip that.
# This is the 3099th spike. We will skip that.
# This is the 3100th spike. We will skip that.
# This is the 3101th spike. We will skip that.
# This is the 3102th spike. We will skip that.
# This is the 3103th spike. We will skip that.
# This is the 3104th spike. We will skip that.
# This is the 3105th spike. We will skip that.
# This is the 3106th spike. We will skip that.
# This is the 3107th spike. We will skip that.
# This is the 3108th spike. We will skip that.
# This is the 3109th spike. We will skip that.
# This is the 3110th spike. We will skip that.
# This is the 3111th spike. We will skip that.
# This is the 3112th spike. We will skip that.
# This is the 3113th spike. We will skip that.
# This is the 3114th spike. We will skip that.
# This is the 3115th spike. We will skip that.
# This is the 3116th spike. We will skip that.
# This is the 3117th spike. We will skip that.
# This is the 3118th spike. We will skip that.
# This is the 3119th spike. We will skip that.
# This is the 3120th spike. We will skip that.
# This is the 3121th spike. We will skip that.
# This is the 3122th spike. We will skip that.
# This is the 3123th spike. We will skip that.
# This is the 3124th spike. We will skip that.
# This is the 3125th spike. We will skip that.
# This is the 3126th spike. We will skip that.
# This is the 3127th spike. We will skip that.
# This is the 3128th spike. We will skip that.
# This is the 3129th spike. We will skip that.
# This is the 3130th spike. We will skip that.
# This is the 3131th spike. We will skip that.
# This is the 3132th spike. We will skip that.
# This is the 3133th spike. We will skip that.
# This is the 3134th spike. We will skip that.
# This is the 3135th spike. We will skip that.
# This is the 3136th spike. We will skip that.
# This is the 3137th spike. We will skip that.
# This is the 3138th spike. We will skip that.
# This is the 3139th spike. We will skip that.
# This is the 3140th spike. We will skip that.
# This is the 3141th spike. We will skip that.
# This is the 3142th spike. We will skip that.
# This is the 3143th spike. We will skip that.
# This is the 3144th spike. We will skip that.
# This is the 3145th spike. We will skip that.
# This is the 3146th spike. We will skip that.
# This is the 3147th spike. We will skip that.
# This is the 3148th spike. We will skip that.
# This is the 3149th spike. Finally filtered.
# This is the 3150th spike. We will skip that.
# This is the 3151th spike. We will skip that.
# This is the 3152th spike. We will skip that.
# This is the 3153th spike. We will skip that.
# This is the 3154th spike. We will skip that.
# This is the 3155th spike. We will skip that.
# This is the 3156th spike. We will skip that.
# This is the 3157th spike. We will skip that.
# This is the 3158th spike. We will skip that.
# This is the 3159th spike. We will skip that.
# This is the 3160th spike. We will skip that.
# This is the 3161th spike. We will skip that.
# This is the 3162th spike. We will skip that.
# This is the 3163th spike. We will skip that.
# This is the 3164th spike. We will skip that.
# This is the 3165th spike. We will skip that.
# This is the 3166th spike. We will skip that.
# This is the 3167th spike. We will skip that.
# This is the 3168th spike. We will skip that.
# This is the 3169th spike. We will skip that.
# This is the 3170th spike. We will skip that.
# This is the 3171th spike. We will skip that.
# This is the 3172th spike. We will skip that.
# This is the 3173th spike. We will skip that.
# This is the 3174th spike. We will skip that.
# This is the 3175th spike. We will skip that.
# This is the 3176th spike. We will skip that.
# This is the 3177th spike. We will skip that.
# This is the 3178th spike. We will skip that.
# This is the 3179th spike. We will skip that.
# This is the 3180th spike. We will skip that.
# This is the 3181th spike. We will skip that.
# This is the 3182th spike. We will skip that.
# This is the 3183th spike. We will skip that.
# This is the 3184th spike. We will skip that.
# This is the 3185th spike. We will skip that.
# This is the 3186th spike. We will skip that.
# This is the 3187th spike. We will skip that.
# This is the 3188th spike. We will skip that.
# This is the 3189th spike. We will skip that.
# This is the 3190th spike. We will skip that.
# This is the 3191th spike. We will skip that.
# This is the 3192th spike. We will skip that.
# This is the 3193th spike. We will skip that.
# This is the 3194th spike. We will skip that.
# This is the 3195th spike. We will skip that.
# This is the 3196th spike. We will skip that.
# This is the 3197th spike. We will skip that.
# This is the 3198th spike. We will skip that.
# This is the 3199th spike. We will skip that.
# This is the 3200th spike. We will skip that.
# This is the 3201th spike. We will skip that.
# This is the 3202th spike. We will skip that.
# This is the 3203th spike. We will skip that.
# This is the 3204th spike. We will skip that.
# This is the 3205th spike. We will skip that.
# This is the 3206th spike. We will skip that.
# This is the 3207th spike. We will skip that.
# This is the 3208th spike. We will skip that.
# This is the 3209th spike. We will skip that.
# This is the 3210th spike. We will skip that.
# This is the 3211th spike. We will skip that.
# This is the 3212th spike. We will skip that.
# This is the 3213th spike. We will skip that.
# This is the 3214th spike. We will skip that.
# This is the 3215th spike. We will skip that.
# This is the 3216th spike. Finally filtered.
# This is the 3217th spike. We will skip that.
# This is the 3218th spike. We will skip that.
# This is the 3219th spike. We will skip that.
# This is the 3220th spike. We will skip that.
# This is the 3221th spike. We will skip that.
# This is the 3222th spike. We will skip that.
# This is the 3223th spike. We will skip that.
# This is the 3224th spike. We will skip that.
# This is the 3225th spike. We will skip that.
# This is the 3226th spike. We will skip that.
# This is the 3227th spike. We will skip that.
# This is the 3228th spike. We will skip that.
# This is the 3229th spike. We will skip that.
# This is the 3230th spike. We will skip that.
# This is the 3231th spike. We will skip that.
# This is the 3232th spike. We will skip that.
# This is the 3233th spike. We will skip that.
# This is the 3234th spike. We will skip that.
# This is the 3235th spike. We will skip that.
# This is the 3236th spike. We will skip that.
# This is the 3237th spike. We will skip that.
# This is the 3238th spike. We will skip that.
# This is the 3239th spike. We will skip that.
# This is the 3240th spike. We will skip that.
# This is the 3241th spike. We will skip that.
# This is the 3242th spike. We will skip that.
# This is the 3243th spike. We will skip that.
# This is the 3244th spike. We will skip that.
# This is the 3245th spike. We will skip that.
# This is the 3246th spike. We will skip that.
# This is the 3247th spike. We will skip that.
# This is the 3248th spike. We will skip that.
# This is the 3249th spike. We will skip that.
# This is the 3250th spike. We will skip that.
# This is the 3251th spike. We will skip that.
# This is the 3252th spike. We will skip that.
# This is the 3253th spike. We will skip that.
# This is the 3254th spike. We will skip that.
# This is the 3255th spike. We will skip that.
# This is the 3256th spike. We will skip that.
# This is the 3257th spike. We will skip that.
# This is the 3258th spike. We will skip that.
# This is the 3259th spike. We will skip that.
# This is the 3260th spike. We will skip that.
# This is the 3261th spike. We will skip that.
# This is the 3262th spike. We will skip that.
# This is the 3263th spike. We will skip that.
# This is the 3264th spike. We will skip that.
# This is the 3265th spike. We will skip that.
# This is the 3266th spike. We will skip that.
# This is the 3267th spike. We will skip that.
# This is the 3268th spike. We will skip that.
# This is the 3269th spike. We will skip that.
# This is the 3270th spike. We will skip that.
# This is the 3271th spike. We will skip that.
# This is the 3272th spike. We will skip that.
# This is the 3273th spike. We will skip that.
# This is the 3274th spike. We will skip that.
# This is the 3275th spike. We will skip that.
# This is the 3276th spike. We will skip that.
# This is the 3277th spike. We will skip that.
# This is the 3278th spike. We will skip that.
# This is the 3279th spike. We will skip that.
# This is the 3280th spike. Finally filtered.
# This is the 3281th spike. We will skip that.
# This is the 3282th spike. We will skip that.
# This is the 3283th spike. We will skip that.
# This is the 3284th spike. We will skip that.
# This is the 3285th spike. We will skip that.
# This is the 3286th spike. We will skip that.
# This is the 3287th spike. We will skip that.
# This is the 3288th spike. Finally filtered.
# This is the 3289th spike. We will skip that.
# This is the 3290th spike. We will skip that.
# This is the 3291th spike. We will skip that.
# This is the 3292th spike. We will skip that.
# This is the 3293th spike. We will skip that.
# This is the 3294th spike. We will skip that.
# This is the 3295th spike. We will skip that.
# This is the 3296th spike. We will skip that.
# This is the 3297th spike. We will skip that.
# This is the 3298th spike. We will skip that.
# This is the 3299th spike. We will skip that.
# This is the 3300th spike. We will skip that.
# This is the 3301th spike. We will skip that.
# This is the 3302th spike. We will skip that.
# This is the 3303th spike. We will skip that.
# This is the 3304th spike. We will skip that.
# This is the 3305th spike. We will skip that.
# This is the 3306th spike. We will skip that.
# This is the 3307th spike. We will skip that.
# This is the 3308th spike. We will skip that.
# This is the 3309th spike. We will skip that.
# This is the 3310th spike. We will skip that.
# This is the 3311th spike. We will skip that.
# This is the 3312th spike. We will skip that.
# This is the 3313th spike. We will skip that.
# This is the 3314th spike. We will skip that.
# This is the 3315th spike. We will skip that.
# This is the 3316th spike. We will skip that.
# This is the 3317th spike. We will skip that.
# This is the 3318th spike. We will skip that.
# This is the 3319th spike. We will skip that.
# This is the 3320th spike. We will skip that.
# This is the 3321th spike. Finally filtered.
# This is the 3322th spike. We will skip that.
# This is the 3323th spike. We will skip that.
# This is the 3324th spike. We will skip that.
# This is the 3325th spike. We will skip that.
# This is the 3326th spike. We will skip that.
# This is the 3327th spike. We will skip that.
# This is the 3328th spike. We will skip that.
# This is the 3329th spike. We will skip that.
# This is the 3330th spike. We will skip that.
# This is the 3331th spike. We will skip that.
# This is the 3332th spike. We will skip that.
# This is the 3333th spike. We will skip that.
# This is the 3334th spike. We will skip that.
# This is the 3335th spike. We will skip that.
# This is the 3336th spike. We will skip that.
# This is the 3337th spike. We will skip that.
# This is the 3338th spike. We will skip that.
# This is the 3339th spike. We will skip that.
# This is the 3340th spike. We will skip that.
# This is the 3341th spike. We will skip that.
# This is the 3342th spike. We will skip that.
# This is the 3343th spike. We will skip that.
# This is the 3344th spike. We will skip that.
# This is the 3345th spike. We will skip that.
# This is the 3346th spike. We will skip that.
# This is the 3347th spike. We will skip that.
# This is the 3348th spike. We will skip that.
# This is the 3349th spike. We will skip that.
# This is the 3350th spike. We will skip that.
# This is the 3351th spike. We will skip that.
# This is the last spike. Filtering is completed.

# %% [markdown]
# ### Calculation of Capacitance With Variance Minimization Method

# %%
experiment_array = experiment_array.T[np.argsort(experiment_array.T[:, 0])]  ## sort the array by increasing values of membrane potential
experiment_array_2 = experiment_array[(experiment_array[:,0] < -60)]         ## store subthreshold data into another array
C_e = np.arange(0,1,0.005)                                ## nF, estimate capacitance (C_e), candidates to be the capacitance (C), each one is used to calculate corresponding varience
                                                          ## as the increment (0.005 nF) gets smaller, accuracy of C increases
var_list = np.array([])                                   ## store the variances in an array to find the minimum
ce = 0
while ce < np.size(C_e):                         
    inj_ce = experiment_array_2[:,1]/C_e[ce]              ## to find [I_inj/C-dVdt], I_inj/C_e values put in a vector
    difference = inj_ce - experiment_array_2[:,3]         ## [I_inj/C-dVdt] values for the current C_e is found
    var_list = np.hstack((var_list,np.var(difference)))   ## var[I_inj/C-dVdt] is calculated and stored 
    ce += 1                                               ## continue with the next C_e
C_e = C_e[~np.isnan(var_list)]                            
var_list = var_list[~np.isnan(var_list)]
minimum = np.argmin(var_list)                             ## find where is the minimum of variance
C = C_e[minimum] *1000
print("Capacitance of cell is " + str(C)+ " pF")
# Out:
# Capacitance of cell is 145.0 pF

# %%
## plot the variance calculated for each C_e. Graph is magnified to show the minimum point. 
plt.figure()
plt.rcParams["figure.figsize"] = (13,7)
plt.rcParams.update({'font.size': 22})
plt.plot(C_e, var_list)
plt.ylim(min(var_list)-5,min(var_list)+5)
plt.xlim(C_e[minimum]-0.3,C_e[minimum]+0.2)
plt.scatter(C_e[minimum], var_list[minimum], color="red", )
plt.annotate("minimum", (C_e[minimum], var_list[minimum]))
plt.ylabel("Var [$I_{in}$/$C_e$ - dV/dt]")
plt.xlabel('$C_e$ (nF)')
#plt.savefig("find_c.png")
# Out:
# Text(0.5, 0, '$C_e$ (nF)')

# %% [markdown]
# ### Calculation of Transmembrane Current (I<sub>m</sub>) and Mean of I<sub>m</sub> in Small Voltage Intervals (I<sub>d</sub>)

# %%
experiment_array_2 = experiment_array[(experiment_array[:,0] > -105) & (experiment_array[:,0] < -45)]

inj_pA = experiment_array_2[:,1]*1000              ## I_inj converted from nA to pA
dvdt_C = experiment_array_2[:,3]*C                 ## For calculating I_ion = I_inj - dvdt*C
I_ion = inj_pA - dvdt_C                            ## Transmembrane current is calculated
experiment_array_2 = np.column_stack((experiment_array_2, I_ion))  ## add I_ion to the dataframe
interval_dictionary = {"STPC": [-105,-50], "UTPC": [-105, -47], "TTPC2": [-105,-48]} ## best EIF fits for these cells are found in these specific voltage intervals
interval_V = interval_dictionary[cell_type]     
I_d = np.array([]) ## store I_d values, found by formula I_d = <I_m> (mean of I_m for little intervals such as V-0.5 mV to V+0.5 mV)
min_max_range = np.arange(interval_V[0], interval_V[1], 0.5)  ## from min to max, every V_m value with increment 0.5 mV
i = 0
while i < len(min_max_range)-1:
    V_interval = experiment_array_2[(experiment_array_2[:,0] > min_max_range[i]) & (experiment_array_2[:,0] < min_max_range[i+1])]
                                                   ## V_m values in the interval V-0.5 mV to V+0.5mV
    I_d = np.append(I_d, np.mean(V_interval[:,4])) ## mean of the interval is found and added as a point of I_d
    i += 1
range_V = np.arange((interval_V[0]+0.25), (interval_V[1]-0.25), 0.5) ## points of means
range_V = range_V[~np.isnan(I_d)]
I_d = I_d[~np.isnan(I_d)]

# %%
## plot I_m-V and I_d-V graphs together 
plt.figure() 
plt.plot(experiment_array_2[:,0], experiment_array_2[:,4], 'o', markersize = 2)
plt.yticks(np.arange(-1500, 2000, 250))
plt.ylim(-1500,2000)
plt.axhline(y=0, color='k', linestyle='dotted')
plt.plot(range_V, I_d, linewidth=4.0, label = "mean of I_m (I_d)")
plt.title("I_ion As a Function of V")
plt.xlabel('V (mV)')
plt.ylabel("I_ion (pA)")
plt.legend()
plt.show()
# plt.savefig("Iion.png")

# %% [markdown]
# ### Calculation of Function of Voltage (F(V)) and Finding the Parameters for the EIF Model

# %%
F_actual = -I_d/C                   ## F(V) = -I_d/C from the article, find each F value for V_m's
## EIF model is fit on the F_actual with curve_fit()
popt, pcov = curve_fit(lambda V, tau, E_m, Vt, delta_t: (1/tau)*(E_m - V + delta_t * np.exp((V-Vt)/delta_t)),  np.array(range_V),  np.array(F_actual).flatten(),p0 = [10,-72,-55,1.5])
tau, E_m, Vt, delta_t = popt        ## parameters are saved
    
F_fit = (1/tau)*(E_m-range_V+delta_t*np.exp((range_V - Vt)/delta_t)) ## Find each F_fit value for V_m's

## Calculating r_square of the fit
F_array = np.array(F_actual)
F_array = np.reshape(F_array, (len(F_array),))
F_fit_array = np.array(F_fit)

sum1 = sum((F_array - F_fit_array)**2)
sum2 = sum((F_array - np.mean(F_fit_array))**2)
r_sq = 1 - (sum1/sum2)

# %%
## plot the I_m-V and I_d-V, together with F(V)-V and EIF Fit-V
fig, (ax1, ax2) = plt.subplots(1,2)
fig.tight_layout()
fig.subplots_adjust(hspace=0.5)
fig.suptitle("$I_m$ Curve and F(V) Curve with EIF Fit For \n NEURON Cell = L5 " + cell_type, y=1.12)
ax1.plot(experiment_array_2[:,0], experiment_array_2[:,4], 'o', markersize = 2)
ax1.plot(range_V, I_d,linestyle='-', color='k')
ax1.set_yticks(np.arange(-1500, 2000, 250))
ax1.set_ylim(-1500,2000)
ax1.axhline(y=0, color='k', linestyle='dotted')
ax1.set_title("$I_{ion}$ As a Function of V")
ax1.set_xlabel('V (mV)')
ax1.set_ylabel("$I_{ion}$ (pA)")
ax2.plot(range_V,F_actual, marker='o', color='b', label="Dynamic I-V Data from NEURON Model")
ax2.plot(range_V,F_fit, linestyle='-', color='k', label="Fit to EIF Model")
ax2.set_title("Quantification of Dynamic I-V Curve")
ax2.axhline(y=0, color='k', linestyle='dotted')
ax2.set_xlabel("V (mV)")
ax2.set_ylabel("F(V) (mV/ms)")
plt.legend(fontsize=13)
plt.show()

# %%
print("Experiment with 8 types of input, each input with stimulation time of 40 seconds of combined OU processes.")
print("Results are: Capacitance = "+str(C)+
            ", Parameters of the fit: tau= "+str(popt[0])+" ms, V_rest= " + str(popt[1])+" mV, V_thres= "+str(popt[2])+" mV, delta_t= "+ str(popt[3])+" mV")
print("Error of the fit is "+str(r_sq)+ " and error for parameters: " + str(np.diag(pcov)))
# Out:
# Experiment with 8 types of input, each input with stimulation time of 40 seconds of combined OU processes.
# Results are: Capacitance = 145.0, Parameters of the fit: tau= 8.821281021338537 ms, V_rest= -78.35511686607575 mV, V_thres= -56.30568012603345 mV, delta_t= 1.9398713014792863 mV
# Error of the fit is 0.9976596045576619 and error for parameters: [0.00425791 0.01144828 0.00310883 0.00036836]
